# %%
from __future__ import division
from math import exp
from numpy import *
import numpy as np
from random import normalvariate
import pandas as pd
# reference
# https://segmentfault.com/a/1190000020254554
# https://blog.csdn.net/john_xyz/article/details/78933253

# %%
#与FM相比，修改读入数据，xgb输出后的one-hot；数据预处理去掉归一化
train_data = 'fm_data/xgb_train.txt'
test_data = 'fm_data/xgb_test.txt'

def preprocess(data):
    feature=np.array(data.iloc[:,:-1])
    label=data.iloc[:,-1].map(lambda x: 1 if x==1 else -1)
    label=np.array(label)
    return feature,label

def sigmoid(x):
    return 1.0 / (1 + exp(-x))

# %%
def SGD_FM(data, label, k, iter):
    m, num_feature = shape(data)
    alpha = 0.01
    w = zeros((num_feature, 1))#一阶特征的系数
    w_0 = 0.0
    v = normalvariate(0, 0.2) * ones((num_feature, k))   #即生成辅助向量，用来训练二阶交叉特征的系数

    for it in range(iter):
        true_loss = 0.0
        false_loss = 0.0
        for x in range(m):
            fm_1 = data[x] * v
            fm_2 = multiply(data[x], data[x]) * multiply(v, v)
            fm = sum(multiply(fm_1, fm_1) - fm_2) / 2.
            y = w_0 + data[x] * w + fm  # FM预测输出
            loss = sigmoid(label[x] * y[0, 0])-1    #真实损失过大，与真实损失相像。loss针对当前样本，不做为最后loss衡量
            true_loss += -np.log(sigmoid(label[x] * y[0, 0]))
            false_loss += -loss
            w_0 -= alpha * loss * label[x]
            for i in range(num_feature):
                if data[x, i] != 0:
                    w[i, 0] -= alpha * loss * label[x] * data[x, i]
                    for j in range(k):
                        v[i, j] -= alpha * loss * label[x] * (data[x, i] * fm_1[0, j] - v[i, j] * data[x, i] * data[x, i])
        print("第{}次迭代后真损失为{}，假损失为{}".format(it, true_loss, false_loss))
    return w_0, w, v
def predict(data, label, w_0, w, v):
    m, _ = shape(data)
    err = 0
    num = 0
    result = []
    for x in range(m):   #计算每一个样本的误差
        num += 1
        fm_1 = data[x] * v
        fm_2 = multiply(data[x], data[x]) * multiply(v, v)
        fm = sum(multiply(fm_1, fm_1) - fm_2) / 2.
        y = w_0 + data[x] * w + fm  # 计算预测的输出
        prop = sigmoid(y[0, 0])
        result.append(prop)
        if prop < 0.5 and label[x] == 1.0:
            err += 1
        elif prop >= 0.5 and label[x] == -1.0:
            err += 1
        else:
            continue
    return float(err) / num

# %%
train = pd.read_csv(train_data,header=None)
test = pd.read_csv(test_data,header=None)
x_train, y_train = preprocess(train)
x_test, y_test = preprocess(test)
w_0, w, v = SGD_FM(mat(x_train), y_train, 20, 200)
print("xgb+fm 训练集acc：%f" % (1 - predict(mat(x_train), y_train, w_0, w, v)))
print("xgb+fm 测试集acc：%f" % (1 - predict(mat(x_test), y_test, w_0, w, v)))
# Out:
# 第0次迭代后真损失为8406.334882724761，假损失为210.6303125906377
# 第1次迭代后真损失为1428.766441221198，假损失为116.56587913917106
# 第2次迭代后真损失为654.8476676542087，假损失为79.01315163723822
# 第3次迭代后真损失为355.8367402548686，假损失为60.40939294130539
# 第4次迭代后真损失为212.99210928587206，假损失为49.059937795199744
# 第5次迭代后真损失为132.92017519837785，假损失为40.339982087439715
# 第6次迭代后真损失为88.71008355202841，假损失为33.6946359800224
# 第7次迭代后真损失为65.19222372609495，假损失为28.037475174930975
# 第8次迭代后真损失为51.98021889581952，假损失为24.027077212748292
# 第9次迭代后真损失为43.049743771928554，假损失为21.2287275380625
# 第10次迭代后真损失为36.31249563714528，假损失为19.048047736726524
# 第11次迭代后真损失为30.986794824655934，假损失为17.233395158833943
# 第12次迭代后真损失为26.63209179522747，假损失为15.678409074341577
# 第13次迭代后真损失为22.94277552292733，假损失为14.350907654958323
# 第14次迭代后真损失为19.725672200248404，假损失为13.194093489290044
# 第15次迭代后真损失为16.90847419819993，假损失为12.120707034853313
# 第16次迭代后真损失为14.519017666524908，假损失为11.091191876331441
# 第17次迭代后真损失为12.57743648835995，假损失为10.126373083683001
# 第18次迭代后真损失为11.029745980921003，假损失为9.247202892623074
# 第19次迭代后真损失为9.792406767821424，假损失为8.464107808762705
# 第20次迭代后真损失为8.791742241987327，假损失为7.778294868884153
# 第21次迭代后真损失为7.973199567041163，假损失为7.182468767489267
# 第22次迭代后真损失为7.296970282612519，假损失为6.666058157111152
# 第23次迭代后真损失为6.732694162710662，假损失为6.218165895509927
# 第24次迭代后真损失为6.256662077134034，假损失为5.828462519709073
# 第25次迭代后真损失为5.850417089258628，假损失为5.487620319148139
# 第26次迭代后真损失为5.4997439538167106，假损失为5.187583571761544
# 第27次迭代后真损失为5.1937640013140385，假损失为4.921625920086457
# 第28次迭代后真损失为4.9241469974538505，假损失为4.684242782179305
# 第29次迭代后真损失为4.684474440116396，假损失为4.470969347231261
# 第30次迭代后真损失为4.46975282003378，假损失为4.278188835142745
# 第31次迭代后真损失为4.276052851601499，假损失为4.102961569917469
# 第32次迭代后真损失为4.100245632295686，假损失为3.942883934617929
# 第33次迭代后真损失为3.9398101370308045，假损失为3.795976292157762
# 第34次迭代后真损失为3.7926921614323454，假损失为3.6605954655759385
# 第35次迭代后真损失为3.6572001374783434，假损失为3.535366828021672
# 第36次迭代后真损失为3.5319274178575473，假损失为3.4191316096654876
# 第37次迭代后真损失为3.415693677840545，假损失为3.31090586424385
# 第38次迭代后真损失为3.3075002445301878，假损失为3.2098483342773507
# 第39次迭代后真损失为3.206495672921023，假损失为3.115235114723956
# 第40次迭代后真损失为3.1119489394445674，假损失为3.0264395308642276
# 第41次迭代后真损失为3.023228357808706，假损失为2.942916037718823
# 第42次迭代后真损失为2.9397848377769513，假损失为2.8641872413149
# 第43次迭代后真损失为2.861138472907799，假损失为2.7898333602979877
# 第44次迭代后真损失为2.786867704418968，假损失为2.7194836088001226
# 第45次迭代后真损失为2.7166004967656967，假损失为2.6528091026992358
# 第46次迭代后真损失为2.6500070977842634，假损失为2.58951698228667
# 第47次迭代后真损失为2.5867940571961343，假损失为2.5293455128671427
# 第48次迭代后真损失为2.526699252192832，假损失为2.4720599767715448
# 第49次迭代后真损失为2.469487724933841，假损失为2.4174492099183857
# 第50次迭代后真损失为2.4149481791750707，假损失为2.3653226665232014
# 第51次迭代后真损失为2.3628900155281296，假损失为2.3155079191107464
# 第52次迭代后真损失为2.313140809631906，假损失为2.2678485193146614
# 第53次迭代后真损失为2.265544156685479，假损失为2.2222021593034
# 第54次迭代后真损失为2.2199578207234176，假损失为2.178439084980289
# 第55次迭代后真损失为2.176252138727513，假损失为2.1364407210690146
# 第56次迭代后真损失为2.134308638916614，假损失为2.0960984753407814
# 第57次迭代后真损失为2.0940188399045043，假损失为2.0573126949667886
# 第58次迭代后真损失为2.055283203288932，假损失为2.0199917525958746
# 第59次迭代后真损失为2.01801021695689，假损失为1.9840512434963804
# 第60次迭代后真损失为1.9821155902083651，假损失为1.9494132781463849
# 第61次迭代后真损失为1.9475215449030827，假损失为1.9160058571477299
# 第62次迭代后真损失为1.9141561893687384，假损失为1.8837623173872495
# 第63次迭代后真损失为1.8819529638894694，假损失为1.8526208400600004
# 第64次迭代后真损失为1.8508501483086326，假损失为1.8225240125719033
# 第65次迭代后真损失为1.820790423701431，假损失为1.7934184375078328
# 第66次迭代后真损失为1.791720481255376，假损失为1.7652543828284122
# 第67次迭代后真损失为1.7635906724847117，假损失为1.7379854682790647
# 第68次迭代后真损失为1.7363546957338292，假损失为1.7115683836866626
# 第69次迭代后真损失为1.7099693146227744，假损失为1.6859626354038444
# 第70次迭代后真损失为1.6843941046779325，假损失为1.6611303176576413
# 第71次迭代后真损失为1.6595912248914246，假损失为1.6370359059818922
# 第72次迭代后真损失为1.6355252113786423，假损失为1.61364607027402
# 第73次迭代后真损失为1.6121627906671536，假损失为1.5909295053265953
# 第74次迭代后真损失为1.5894727104614872，假损失为1.5688567769499595
# 第75次迭代后真损失为1.5674255859960553，假损失为1.547400182031636
# 第76次迭代后真损失为1.5459937603189222，假损失为1.5265336210765073
# 第77次迭代后真损失为1.5251511770482162，假损失为1.5062324819434156
# 第78次迭代后真损失为1.5048732643154001，假损失为1.4864735336430401
# 第79次迭代后真损失为1.48513682875958，假损失为1.467234829191961
# 第80次迭代后真损失为1.4659199585668938，假损失为1.4484956166308514
# 第81次迭代后真损失为1.4472019346632115，假损失为1.4302362574142826
# 第82次迭代后真损失为1.4289631492672856，假损失为1.412438151466144
# 第83次迭代后真损失为1.4111850310988852，假损失为1.3950836682712553
# 第84次迭代后真损失为1.3938499766126358，假损失为1.3781560834407078
# 第85次迭代后真损失为1.3769412866956767，假损失为1.3616395202477523
# 第86次迭代后真损失为1.3604431083263435，假损失为1.3455188956832491
# 第87次迭代后真损失为1.3443403807434589，假损失为1.329779870625977
# 第88次迭代后真损失为1.3286187857220528，假损失为1.314408803764025
# 第89次迭代后真损失为1.3132647015922656，假损失为1.2993927089398944
# 第90次迭代后真损失为1.2982651606745632，假损失为1.284719215624191
# 第91次迭代后真损失为1.283607809836686，假损失为1.2703765322516414
# 第92次迭代后真损失为1.269280873906561，假损失为1.2563534121787971
# 第93次迭代后真损失为1.2552731217009467，假损失为1.2426391220456425
# 第94次迭代后真损失为1.2415738344525706，假损失为1.2292234123439374
# 第95次迭代后真损失为1.2281727764388797，假损失为1.2160964900133129
# 第96次迭代后真损失为1.2150601676339605，假损失为1.2032489929027292
# 第97次迭代后真损失为1.202226658221417，假损失为1.1906719659495186
# 第98次迭代后真损失为1.1896633048210188，假损失为1.178356838941701
# 第99次迭代后真损失为1.177361548294786，假损失为1.1662954057409243
# 第100次迭代后真损失为1.1653131930105256，假损失为1.1544798048544753
# 第101次迭代后真损失为1.1535103874512636，假损失为1.1429025012542493
# 第102次迭代后真损失为1.141945606068778，假损失为1.1315562693494343
# 第103次迭代后真损失为1.130611632288282，假损失为1.120434177027596
# 第104次迭代后真损失为1.1195015425791024，假损失为1.1095295706860435
# 第105次迭代后真损失为1.1086086915134072，假损失为1.0988360611817956
# 第106次迭代后真损失为1.0979266977415583，假损失为1.0883475106344465
# 第107次迭代后真损失为1.0874494308184222，假损失为1.0780580200214778
# 第108次迭代后真损失为1.0771709988204834，假损失为1.06796191751056
# 第109次迭代后真损失为1.067085736698315，假损失为1.0580537474777059
# 第110次迭代后真损失为1.057188195313534，假损失为1.0483282601642994
# 第111次迭代后真损失为1.0474731311131555，假损失为1.0387804019294964
# 第112次迭代后真损失为1.0379354963982321，假损失为1.029405306058108
# 第113次迭代后真损失为1.0285704301467815，假损失为1.0201982840869603
# 第114次迭代后真损失为1.0193732493540941，假损失为1.0111548176155474
# 第115次迭代后真损失为1.0103394408565014，假损失为1.0022705505694902
# 第116次迭代后真损失为1.001464653606925，假损失为0.9935412818874659
# 第117次迭代后真损失为0.992744691373147，假损失为0.984962958604585
# 第118次迭代后真损失为0.9841755058317982，假损失为0.9765316693071396
# 第119次迭代后真损失为0.9757531900329385，假损失为0.9682436379353588
# 第120次迭代后真损失为0.967473972212078，假损失为0.9600952179126273
# 第121次迭代后真损失为0.9593342099279852，假损失为0.9520828865810094
# 第122次迭代后真损失为0.9513303845063513，假损失为0.9442032399244974
# 第123次迭代后真损失为0.9434590957705384，假损失为0.9364529875624878
# 第124次迭代后真损失为0.9357170570421994，假损失为0.9288289479974245
# 第125次迭代后真损失为0.9281010903955671，假损失为0.9213280441014828
# 第126次迭代后真损失为0.9206081221503559，假损失为0.9139472988282276
# 第127次迭代后真损失为0.9132351785893275，假损失为0.9066838311362015
# 第128次迭代后真损失为0.9059793818873654，假损失为0.8995348521121499
# 第129次迭代后真损失为0.8988379462398965，假损失为0.8924976612824849
# 第130次迭代后真损失为0.8918081741792646，假损失为0.8855696431023363
# 第131次迭代后真损失为0.8848874530683385，假损失为0.8787482636121287
# 第132次迭代后真损失为0.8780732517614659，假损失为0.8720310672524203
# 第133次迭代后真损失为0.8713631174233889，假损失为0.8654156738282099
# 第134次迭代后真损失为0.8647546724974146，假损失为0.8588997756145248
# 第135次迭代后真损失为0.8582456118146868，假损失为0.8524811345956443
# 第136次迭代后真损失为0.8518336998367875，假损失为0.8461575798306488
# 第137次迭代后真损失为0.845516768024646，假损失为0.8399270049387014
# 第138次迭代后真损失为0.8392927123268293，假损失为0.8337873656975429
# 第139次迭代后真损失为0.8331594907810186，假损失为0.8277366777493624
# 第140次迭代后真损失为0.8271151212226376，假损失为0.8217730144083892
# 第141次迭代后真损失为0.8211576790950571，假损失为0.8158945045649102
# 第142次迭代后真损失为0.815285295356166，假损失为0.8100993306808584
# 第143次迭代后真损失为0.8094961544762527，假损失为0.804385726872146
# 第144次迭代后真损失为0.8037884925226891，假损失为0.7987519770735472
# 第145次迭代后真损失为0.7981605953268694，假损失为0.7931964132817904
# 第146次迭代后真损失为0.7926107967293998，假损失为0.7877174138731163
# 第147次迭代后真损失为0.7871374768995637，假损失为0.7823134019915174
# 第148次迭代后真损失为0.7817390607254482，假损失为0.776982844004279
# 第149次迭代后真损失为0.7764140162712027，假损失为0.7717242480214379
# 第150次迭代后真损失为0.7711608532982289，假损失为0.7665361624761831
# 第151次迭代后真损失为0.7659781218471373，假损失为0.7614171747631633
# 第152次迭代后真损失为0.7608644108776272，假损失为0.7563659099320309
# 第153次迭代后真损失为0.7558183469634528，假损失为0.7513810294335349
# 第154次迭代后真损失为0.7508385930399701，假损失为0.7464612299157793
# 第155次迭代后真损失为0.7459238472016619，假损失为0.7416052420681953
# 第156次迭代后真损失为0.741072841547445，假损失为0.7368118295111263
# 第157次迭代后真损失为0.7362843410714658，假损失为0.7320797877288717
# 第158次迭代后真损失为0.731557142597279，假损失为0.7274079430441702
# 第159次迭代后真损失为0.7268900737535205，假损失为0.7227951516323606
# 第160次迭代后真损失为0.722281991989074，假损失为0.7182402985732752
# 第161次迭代后真损失为0.717731783626051，假损失为0.713742296939319
# 第162次迭代后真损失为0.7132383629488122，假损失为0.7093000869180173
# 第163次迭代后真损失为0.7088006713275217，假损失为0.7049126349676089
# 第164次迭代后真损失为0.7044176763745846，假损失为0.7005789330041213
# 第165次迭代后真损失为0.7000883711326666，假损失为0.6962979976186825
# 第166次迭代后真损失为0.6958117732927913，假损失为0.6920688693236408
# 第167次迭代后真损失为0.6915869244412917，假损失为0.6878906118263299
# 第168次迭代后真损失为0.6874128893343573，假损失为0.6837623113292808
# 第169次迭代后真损失为0.6832887551989952，假损失为0.6796830758557486
# 第170次迭代后真损失为0.6792136310592549，假损失为0.6756520345994764
# 第171次迭代后真损失为0.6751866470867296，假损失为0.6716683372977247
# 第172次迭代后真损失为0.6712069539741907，假损失为0.6677311536265095
# 第173次迭代后真损失为0.6672737223315329，假损失为0.6638396726172495
# 第174次迭代后真损失为0.6633861421029983，假损失为0.6599931020938281
# 第175次迭代后真损失为0.6595434220048564，假损失为0.6561906681293083
# 第176次迭代后真损失为0.6557447889826846，假损失为0.6524316145214619
# 第177次迭代后真损失为0.6519894876874657，假损失为0.6487152022863802
# 第178次迭代后真损失为0.6482767799697126，假损失为0.6450407091694079
# 第179次迭代后真损失为0.6446059443909616，假损失为0.6414074291727621
# 第180次迭代后真损失为0.6409762757518348，假损失为0.6378146720990882
# 第181次迭代后真损失为0.6373870846361461，假损失为0.6342617631104406
# 第182次迭代后真损失为0.633837696970266，假损失为0.6307480423019328
# 第183次迭代后真损失为0.630327453597319，假损失为0.6272728642896677
# 第184次迭代后真损失为0.62685570986547，假损失为0.6238355978122135
# 第185次迭代后真损失为0.6234218352298472，假损失为0.6204356253452147
# 第186次迭代后真损失为0.6200252128676008，假损失为0.6170723427286422
# 第187次迭代后真损失为0.6166652393054745，假损失为0.6137451588060903
# 第188次迭代后真损失为0.6133413240595418，假损失为0.6104534950757997
# 第189次迭代后真损失为0.6100528892865703，假损失为0.6071967853528679
# 第190次迭代后真损失为0.6067993694466316，假损失为0.6039744754423081
# 第191次迭代后真损失为0.6035802109764209，假损失为0.6007860228224218
# 第192次迭代后真损失为0.6003948719730599，假损失为0.5976308963382732
# 第193次迭代后真损失为0.5972428218878478，假损失为0.5945085759047725
# 第194次迭代后真损失为0.5941235412296498，假损失为0.5914185522190272
# 第195次迭代后真损失为0.5910365212776018，假损失为0.5883603264817018
# 第196次迭代后真损失为0.587981263802713，假损失为0.5853334101269528
# 第197次迭代后真损失为0.5849572807981184，假损失为0.5823373245607004
# 第198次迭代后真损失为0.581964094217625，假损失为0.5793716009069275
# 第199次迭代后真损失为0.5790012357222819，假损失为0.5764357797617014
# xgb+fm 训练集acc：1.000000
# xgb+fm 测试集acc：0.715356
