# %%
from __future__ import division
from math import exp
from numpy import *
import numpy as np
from random import normalvariate
import pandas as pd
# reference
# https://segmentfault.com/a/1190000020254554
# https://blog.csdn.net/john_xyz/article/details/78933253

# %%
#与FM相比，修改读入数据，xgb输出后的one-hot；数据预处理去掉归一化
train_data = 'fm_data/xgb_train.txt'
test_data = 'fm_data/xgb_test.txt'

def preprocess(data):
    feature=np.array(data.iloc[:,:-1])
    label=data.iloc[:,-1].map(lambda x: 1 if x==1 else -1)
    label=np.array(label)
    return feature,label

def sigmoid(x):
    return 1.0 / (1 + exp(-x))

# %%
def SGD_FM(data, label, k, iter):
    m, num_feature = shape(data)
    alpha = 0.01
    w = zeros((num_feature, 1))#一阶特征的系数
    w_0 = 0.0
    v = normalvariate(0, 0.2) * ones((num_feature, k))   #即生成辅助向量，用来训练二阶交叉特征的系数

    for it in range(iter):
        true_loss = 0.0
        false_loss = 0.0
        for x in range(m):
            fm_1 = data[x] * v
            fm_2 = multiply(data[x], data[x]) * multiply(v, v)
            fm = sum(multiply(fm_1, fm_1) - fm_2) / 2.
            y = w_0 + data[x] * w + fm  # FM预测输出
            loss = sigmoid(label[x] * y[0, 0])-1    #真实损失过大，与真实损失相像。loss针对当前样本，不做为最后loss衡量
            true_loss += -np.log(sigmoid(label[x] * y[0, 0]))
            false_loss += -loss
            w_0 -= alpha * loss * label[x]
            for i in range(num_feature):
                if data[x, i] != 0:
                    w[i, 0] -= alpha * loss * label[x] * data[x, i]
                    for j in range(k):
                        v[i, j] -= alpha * loss * label[x] * (data[x, i] * fm_1[0, j] - v[i, j] * data[x, i] * data[x, i])
        print("第{}次迭代后真损失为{}，假损失为{}".format(it, true_loss, false_loss))
    return w_0, w, v
def predict(data, label, w_0, w, v):
    m, _ = shape(data)
    err = 0
    num = 0
    result = []
    for x in range(m):   #计算每一个样本的误差
        num += 1
        fm_1 = data[x] * v
        fm_2 = multiply(data[x], data[x]) * multiply(v, v)
        fm = sum(multiply(fm_1, fm_1) - fm_2) / 2.
        y = w_0 + data[x] * w + fm  # 计算预测的输出
        prop = sigmoid(y[0, 0])
        result.append(prop)
        if prop < 0.5 and label[x] == 1.0:
            err += 1
        elif prop >= 0.5 and label[x] == -1.0:
            err += 1
        else:
            continue
    return float(err) / num

# %%
train = pd.read_csv(train_data)
test = pd.read_csv(test_data)
x_train, y_train = preprocess(train)
x_test, y_test = preprocess(test)
w_0, w, v = SGD_FM(mat(x_train), y_train, 20, 200)
print("训练集acc：%f" % (1 - predict(mat(x_train), y_train, w_0, w, v)))
print("测试集acc：%f" % (1 - predict(mat(x_test), y_test, w_0, w, v)))
# Out:
# 第0次迭代后真损失为5639.592912342595，假损失为207.30214221716773
# 第1次迭代后真损失为946.2647251136234，假损失为111.00812591365998
# 第2次迭代后真损失为430.5663029537502，假损失为75.61740640936961
# 第3次迭代后真损失为235.06152972570186，假损失为57.06018562934807
# 第4次迭代后真损失为141.06702125553775，假损失为46.20783923391546
# 第5次迭代后真损失为90.38387129754874，假损失为38.02062275232458
# 第6次迭代后真损失为63.734571376230754，假损失为31.39637066264236
# 第7次迭代后真损失为49.91504996862862，假损失为26.604638399710193
# 第8次迭代后真损失为41.26084465352702，假损失为23.3704222809332
# 第9次迭代后真损失为34.9539089968962，假损失为20.95802601828652
# 第10次迭代后真损失为30.039643630515943，假损失为19.0114003281696
# 第11次迭代后真损失为26.064739605832443，假损失为17.3779979273766
# 第12次迭代后真损失为22.75140849542275，假损失为15.97938045003641
# 第13次迭代后真损失为19.925441332863837，假损失为14.749613954530298
# 第14次迭代后真损失为17.49104360234007，假损失为13.624052033193838
# 第15次迭代后真损失为15.408643279569597，假损失为12.559958676799196
# 第16次迭代后真损失为13.664844378040945，假损失为11.55602020799293
# 第17次迭代后真损失为12.234669818487351，假损失为10.638342121933174
# 第18次迭代后真损失为11.067840596731354，假损失为9.824745617558564
# 第19次迭代后真损失为10.10755510015412，假损失为9.113607846494244
# 第20次迭代后真损失为9.306535231799844，假损失为8.49354010699269
# 第21次迭代后真损失为8.629299847880118，假损失为7.951327199370322
# 第22次迭代后真损失为8.049596708680385，假损失为7.474813360394778
# 第23次迭代后真损失为7.547804655929615，假损失为7.053580084351347
# 第24次迭代后真损失为7.109062442177773，假损失为6.678937107505181
# 第25次迭代后真损失为6.7219710668274795，假损失为6.3437199650879785
# 第26次迭代后真损失为6.377681637288172，假损失为6.0420472829073795
# 第27次迭代后真损失为6.069244159991101，假损失为5.769090363431979
# 第28次迭代后真损失为5.791137384283192，假损失为5.52087314210685
# 第29次迭代后真损失为5.538926346915188，假损失为5.294106297031404
# 第30次迭代后真损失为5.3090108137743295，假损失为5.086053130105443
# 第31次迭代后真损失为5.098438839713197，假损失为4.894422593442455
# 第32次迭代后真损失为4.904767275277671，假损失为4.717284486948147
# 第33次迭代后真损失为4.725956364312361，假损失为4.55300232175271
# 第34次迭代后真损失为4.560289299562135，假损失为4.400180077343263
# 第35次迭代后真损失为4.406310213095232，假损失为4.257619821977218
# 第36次迭代后真损失为4.262775910812475，假损失为4.124287815872779
# 第37次迭代后真损失为4.128617951594095，假损失为3.9992872489119495
# 第38次迭代后真损失为4.002912586426377，假损失为3.881836185175925
# 第39次迭代后真损失为3.88485672524835，假损失为3.771249612622045
# 第40次迭代后真损失为3.773748568076837，假损失为3.66692474637769
# 第41次迭代后真损失为3.668971876641232，假损失为3.5683289252969903
# 第42次迭代后真损失为3.569983110969216，假损失为3.47498958742549
# 第43次迭代后真损失为3.47630083831578，假损失为3.3864859217156074
# 第44次迭代后真损失为3.38749695784441，假损失为3.302441879069611
# 第45次迭代后真损失为3.30318938645285，假损失为3.2225202918736686
# 第46次迭代后真损失为3.223035928235673，假损失为3.1464179023746954
# 第47次迭代后真损失为3.1467291088320395，假损失为3.073861140108617
# 第48次迭代后真损失为3.073991801028997，假损失为3.0046025197887714
# 第49次迭代后真损失为3.004573502899607，假损失为2.9384175556204966
# 第50次迭代后真损失为2.9382471569538398，假损失为2.8751021074412417
# 第51次迭代后真损失为2.874806420114869，假损失为2.814470089546705
# 第52次迭代后真损失为2.814063311176174，假损失为2.7563514854271487
# 第53次迭代后真损失为2.755846175773564，假损失为2.700590621576671
# 第54次迭代后真损失为2.6999979195948707，假损失为2.647044661565143
# 第55次迭代后真损失为2.646374469137704，假损失为2.5955822880767587
# 第56次迭代后真损失为2.5948434262616504，假损失为2.5460825459305005
# 第57次迭代后真损失为2.5452828884115597，假损失为2.4984338234462053
# 第58次迭代后真损失为2.4975804109814344，假损失为2.4525329530964113
# 第59次迭代后真损失为2.4516320920517365，假损失为2.408284415336724
# 第60次迭代后真损失为2.407341762830832，假损失为2.3655996319553814
# 第61次迭代后真损失为2.364620269691416，假损失为2.324396337319034
# 第62次迭代后真损失为2.3233848358178273，假损失为2.2845980175929697
# 第63次迭代后真损失为2.2835584922504415，假损失为2.246133409439227
# 第64次迭代后真损失为2.2450695695933978，假损失为2.2089360508947293
# 第65次迭代后真损失为2.207851242894792，假损失为2.1729438781430535
# 第66次迭代后真损失为2.171841123254141，假损失为2.1380988627492026
# 第67次迭代后真损失为2.1369808905962695，假损失为2.1043466846534247
# 第68次迭代后真损失为2.103215962799784，假损失为2.0716364368388827
# 第69次迭代后真损失为2.0704951970055663，假损失为2.0399203581162335
# 第70次迭代后真损失为2.0387706194736004，假损失为2.0091535909205644
# 第71次迭代后真损失为2.0079971808215027，假损失为1.9792939614045886
# 第72次迭代后真损失为1.9781325338761164，假损失为1.9503017794463222
# 第73次迭代后真损失为1.949136831712334，假损失为1.9221396564779338
# 第74次迭代后真损失为1.920972543748681，假损失为1.8947723392922056
# 第75次迭代后真损失为1.8936042880243915，假损失为1.8681665581993987
# 第76次迭代后真损失为1.866998678003855，假损失为1.8422908880954012
# 第77次迭代后真损失为1.8411241824464695，假损失为1.8171156211660344
# 第78次迭代后真损失为1.8159509970471261，假损失为1.7926126500953914
# 第79次迭代后真损失为1.7914509266981669，假损失为1.768755360771137
# 第80次迭代后真损失为1.7675972773515118，假损失为1.7455185335895793
# 第81次迭代后真损失为1.744364756571079，假损失为1.7228782525596102
# 第82次迭代后真损失为1.7217293819636994，假损失为1.7008118214892805
# 第83次迭代后真损失为1.6996683967630963，假损失为1.679297686613769
# 第84次迭代后真损失为1.678160191917447，假损失为1.6583153650894733
# 第85次迭代后真损失为1.6571842340979526，假损失为1.637845378837224
# 第86次迭代后真损失为1.6367209991055487，假损失为1.6178691932697207
# 第87次迭代后真损失为1.6167519102051118，假损失为1.5983691604840193
# 第88次迭代后真损失为1.5972592809634263，假损失为1.5793284665410372
# 第89次迭代后真损失为1.5782262622085401，假损失为1.5607310824902507
# 第90次迭代后真损失为1.5596367927651427，假损失为1.542561718830485
# 第91次迭代后真损失为1.5414755536534575，假损失为1.524805783126587
# 第92次迭代后真损失为1.5237279254687492，假损失为1.507449340527895
# 第93次迭代后真损失为1.5063799486846048，假损失为1.4904790769575877
# 第94次迭代后真损失为1.4894182866470231，假损失为1.473882264763002
# 第95次迭代后真损失为1.4728301910472401，假损失为1.4576467306357301
# 第96次迭代后真损失为1.456603469680463，假损失为1.4417608256272685
# 第97次迭代后真损失为1.4407264563145141，假损失为1.4262133971011157
# 第98次迭代后真损失为1.425187982508111，假损失为1.4109937624761124
# 第99次迭代后真损失为1.409977351232083，假损失为1.396091684628046
# 第100次迭代后真损失为1.3950843121595802，假损失为1.3814973488279427
# 第101次迭代后真损失为1.3804990385026064，假损失为1.3672013411054798
# 第102次迭代后真损失为1.3662121052823708，假损失为1.3531946279352005
# 第103次迭代后真损失为1.3522144689305224，假损失为1.3394685371517367
# 第104次迭代后真损失为1.338497448126406，假损失为1.3260147400074844
# 第105次迭代后真损失为1.3250527057834816，假损失为1.3128252342934785
# 第106次迭代后真损失为1.311872232104812，假损失为1.2998923284502049
# 第107次迭代后真损失为1.2989483286339316，假损失为1.2872086266009743
# 第108次迭代后真损失为1.2862735932332172，假损失为1.274767014445641
# 第109次迭代后真损失为1.2738409059270985，假损失为1.2625606459572314
# 第110次迭代后真损失为1.261643415552307，假损失为1.2505829308284602
# 第111次迭代后真损失为1.2496745271617542，假损失为1.2388275226190293
# 第112次迭代后真损失为1.2379278901325885，假损失为1.2272883075582675
# 第113次迭代后真损失为1.2263973869328106，假损失为1.2159593939611377
# 第114次迭代后真损失为1.2150771225040187，假损失为1.2048351022184742
# 第115次迭代后真损失为1.2039614142211028，假损失为1.1939099553254118
# 第116次迭代后真损失为1.1930447823924994，假损失为1.1831786699143452
# 第117次迭代后真损失为1.1823219412671668，假损失为1.1726361477612484
# 第118次迭代后真损失为1.17178779051698，假损失为1.1622774677363314
# 第119次迭代后真损失为1.1614374071653133，假损失为1.152097878172097
# 第120次迭代后真损失为1.151266037934726，假损失为1.1420927896236541
# 第121次迭代后真损失为1.1412690919884214，假损失为1.1322577679978216
# 第122次迭代后真损失为1.1314421340420684，假损失为1.1225885280293793
# 第123次迭代后真损失为1.121780877823965，假损失为1.1130809270839683
# 第124次迭代后真损失为1.1122811798631285，假损失为1.1037309592686944
# 第125次迭代后真损失为1.1029390335862461，假损失为1.0945347498327833
# 第126次迭代后真损失为1.0937505637056322，假损失为1.0854885498415863
# 第127次迭代后真损失为1.0847120208815815，假损失为1.0765887311085738
# 第128次迭代后真损失为1.075819776643498，假损失为1.0678317813706935
# 第129次迭代后真损失为1.0670703185553008，假损失为1.0592142996936702
# 第130次迭代后真损失为1.0584602456114465，假损失为1.0507329920944142
# 第131次迭代后真损失为1.0499862638507695，假损失为1.042384667368692
# 第132次迭代后真损失为1.0416451821762531，假损失为1.0341662331128951
# 第133次迭代后真损失为1.0334339083694408，假损失为1.02607469192939
# 第134次迭代后真损失为1.025349445289041，假损失为1.0181071378056852
# 第135次迭代后真损失为1.0173888872437724，假损失为1.0102607526580987
# 第136次迭代后真损失为1.0095494165302519，假损失为1.002532803031336
# 第137次迭代后真损失为1.0018283001271828，假损失为0.9949206369457549
# 第138次迭代后真损失为0.9942228865376411，假损失为0.9874216808846873
# 第139次迭代后真损失为0.9867306027717783，假损失为0.9800334369145733
# 第140次迭代后真损失为0.9793489514627253，假损失为0.9727534799311612
# 第141次迭代后真损失为0.9720755081087963，假损失为0.9655794550252982
# 第142次迭代后真损失为0.9649079184356524，假损失为0.958509074962347
# 第143次迭代后真损失为0.9578438958723612，假损失为0.9515401177695445
# 第144次迭代后真损失为0.950881219135567，假损失为0.9446704244258644
# 第145次迭代后真损失为0.9440177299165332，假损失为0.9378978966494487
# 第146次迭代后真损失为0.9372513306658313，假损失为0.9312204947777006
# 第147次迭代后真损失为0.9305799824710275，假损失为0.924636235735663
# 第148次迭代后真损失为0.9240017030227138，假损失为0.9181431910882951
# 第149次迭代后真损失为0.917514564664713，假损失为0.9117394851727253
# 第150次迭代后真损失为0.9111166925243642，假损失为0.9054232933066126
# 第151次迭代后真损失为0.9048062627191048，假损失为0.8991928400690562
# 第152次迭代后真损失为0.8985815006356835，假损失为0.8930463976506029
# 第153次迭代后真损失为0.892440679278659，假损失为0.8869822842691625
# 第154次迭代后真损失为0.8863821176849092，假损失为0.8809988626487794
# 第155次迭代后真损失为0.8804041794010855，假损失为0.875094538558343
# 第156次迭代后真损失为0.8745052710211324，假损失为0.8692677594075148
# 第157次迭代后真损失为0.8686838407811072，假损失为0.8635170128972552
# 第158次迭代后真损失为0.8629383772087027，假损失为0.8578408257225115
# 第159次迭代后真损失为0.8572674078250161，假损失为0.8522377623247304
# 第160次迭代后真损失为0.8516694978961772，假损失为0.8467064236919162
# 第161次迭代后真损失为0.846143249232666，假损失为0.8412454462042279
# 第162次迭代后真损失为0.840687299034156，假损失为0.8358535005230109
# 第163次迭代后真损失为0.8353003187779223，假损失为0.8305292905214446
# 第164次迭代后真损失为0.8299810131488888，假损失为0.825271552254961
# 第165次迭代后真损失为0.8247281190094897，假损失为0.8200790529697118
# 第166次迭代后真损失为0.8195404044076643，假损失为0.8149505901474826
# 第167次迭代后真损失为0.8144166676213157，假损失为0.8098849905854729
# 第168次迭代后真损失为0.8093557362376836，假损失为0.8048811095094679
# 第169次迭代后真损失为0.8043564662661562，假损失为0.7999378297190095
# 第170次迭代后真损失为0.7994177412831186，假损失为0.7950540607632255
# 第171次迭代后真损失为0.7945384716074843，假损失为0.7902287381460277
# 第172次迭代后真损失为0.789717593505626，假损失为0.7854608225594678
# 第173次迭代后真损失为0.7849540684245054，假损失为0.7807492991441045
# 第174次迭代后真损失为0.7802468822518447，假损失为0.7760931767752771
# 第175次迭代后真损失为0.7755950446021914，假损失为0.771491487374202
# 第176次迭代后真损失为0.7709975881279023，假损失为0.7669432852429555
# 第177次迭代后真损失为0.7664535678539577，假损失为0.7624476464223069
# 第178次迭代后真损失为0.761962060535675，假损失为0.7580036680715246
# 第179次迭代后真损失为0.7575221640384563，假损失为0.7536104678693153
# 第180次迭代后真损失为0.7531329967386131，假损失为0.749267183434997
# 第181次迭代后真损失为0.7487936969444937，假损失为0.7449729717691572
# 第182次迭代后真损失为0.7445034223370681，假损失为0.740727008713005
# 第183次迭代后真损失为0.7402613494293085，假损失为0.736528488425763
# 第184次迭代后真损失为0.7360666730434782，假损失为0.7323766228792786
# 第185次迭代后真损失为0.7319186058057712，假损失为0.7282706413692888
# 第186次迭代后真损失为0.7278163776576021，假损失为0.7242097900427151
# 第187次迭代后真损失为0.7237592353828589，假损失为0.7201933314402851
# 第188次迭代后真损失为0.7197464421505683，假损失为0.7162205440539852
# 第189次迭代后真损失为0.7157772770723891，假损失为0.7122907218987728
# 第190次迭代后真损失为0.7118510347743181，假损失为0.7084031740979679
# 第191次迭代后真损失为0.7079670249821753，假损失为0.7045572244818988
# 第192次迭代后真损失为0.7041245721202479，假损失为0.70075221119922
# 第193次迭代后真损失为0.700323014922694，假损失为0.696987486340508
# 第194次迭代后真损失为0.6965617060571848，假损失为0.6932624155736533
# 第195次迭代后真损失为0.6928400117603377，假损失为0.6895763777905992
# 第196次迭代后真损失为0.6891573114845861，假损失为0.6859287647651071
# 第197次迭代后真损失为0.6855129975559235，假损失为0.6823189808209932
# 第198次迭代后真损失为0.6819064748422936，假损失为0.6787464425106358
# 第199次迭代后真损失为0.6783371604321501，假损失为0.6752105783032786
# 训练集acc：1.000000
# 测试集acc：0.714286
