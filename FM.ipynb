# %%
from __future__ import division
from math import exp
from numpy import *
import numpy as np
from random import normalvariate
import pandas as pd
# reference
# https://segmentfault.com/a/1190000020254554
# https://blog.csdn.net/john_xyz/article/details/78933253

# %%
train_data = 'fm_data/train.txt'
test_data = 'fm_data/test.txt'

def preprocess(data):
    feature=np.array(data.iloc[:,:-1])
    label=data.iloc[:,-1].map(lambda x: 1 if x==1 else -1)
    zmax, zmin = feature.max(axis=0), feature.min(axis=0)
    feature = (feature - zmin) / (zmax - zmin)
    label=np.array(label)
    return feature,label

def sigmoid(x):
    return 1.0 / (1 + exp(-x))

# %%
def SGD_FM(data, label, k, iter):
    m, num_feature = shape(data)
    alpha = 0.01
    w = zeros((num_feature, 1))      #一阶特征的系数
    w_0 = 0.0
    v = normalvariate(0, 0.2) * ones((num_feature, k))   #即生成辅助向量，用来训练二阶交叉特征的系数

    for it in range(iter):
        true_loss = 0.0
        false_loss = 0.0
        for x in range(m):
            fm_1 = data[x] * v
            fm_2 = multiply(data[x], data[x]) * multiply(v, v)
            fm = sum(multiply(fm_1, fm_1) - fm_2) / 2.
            y = w_0 + data[x] * w + fm  # FM预测输出
            loss = sigmoid(label[x] * y[0, 0])-1    #真实损失过大，与真实损失相像。loss针对当前样本，不做为最后loss衡量
            true_loss += -np.log(sigmoid(label[x] * y[0, 0]))
            false_loss += -loss
            w_0 -= alpha * loss * label[x]
            for i in range(num_feature):
                if data[x, i] != 0:
                    w[i, 0] -= alpha * loss * label[x] * data[x, i]
                    for j in range(k):
                        v[i, j] -= alpha * loss * label[x] * (data[x, i] * fm_1[0, j] - v[i, j] * data[x, i] * data[x, i])
        print("第{}次迭代后真损失为{}，假损失为{}".format(it, true_loss, false_loss))
    return w_0, w, v
def predict(data, label, w_0, w, v):
    m, _ = shape(data)
    err = 0
    num = 0
    result = []
    for x in range(m):   #计算每一个样本的误差
        num += 1
        fm_1 = data[x] * v
        fm_2 = multiply(data[x], data[x]) * multiply(v, v)
        fm = sum(multiply(fm_1, fm_1) - fm_2) / 2.
        y = w_0 + data[x] * w + fm  # 计算预测的输出
        prop = sigmoid(y[0, 0])
        result.append(prop)
        if prop < 0.5 and label[x] == 1.0:
            err += 1
        elif prop >= 0.5 and label[x] == -1.0:
            err += 1
        else:
            continue
    return float(err) / num

# %%
if __name__ == '__main__':
    train = pd.read_csv(train_data,header=None)
    test = pd.read_csv(test_data,header=None)
    x_train, y_train = preprocess(train)
    x_test, y_test = preprocess(test)
    w_0, w, v = SGD_FM(mat(x_train), y_train, 20, 200)
    print("fm 训练集acc：%f" % (1 - predict(mat(x_train), y_train, w_0, w, v)))
    print("fm 测试集acc：%f" % (1 - predict(mat(x_test), y_test, w_0, w, v)))
# Out:
# 第0次迭代后真损失为949.5457728541147，假损失为235.39515951177896
# 第1次迭代后真损失为317.83550095560133，假损失为197.63969588205404
# 第2次迭代后真损失为309.88850551180946，假损失为198.57269436571562
# 第3次迭代后真损失为304.26413983441375，假损失为199.02870236962013
# 第4次迭代后真损失为300.10855385549127，假损失为199.09593007787103
# 第5次迭代后真损失为296.84874660936316，假损失为198.86864377684364
# 第6次迭代后真损失为294.14832705167305，假损失为198.42639873634351
# 第7次迭代后真损失为291.8081939874697，假损失为197.83192074354582
# 第8次迭代后真损失为289.70891524475763，假损失为197.13269595476766
# 第9次迭代后真损失为287.7777538584346，假损失为196.36375726840114
# 第10次迭代后真损失为285.9697413142529，假损失为195.55051073477395
# 第11次迭代后真损失为284.2567021206591，假损失为194.71116390865654
# 第12次迭代后真损失为282.62080673186773，假损失为193.85865682026275
# 第13次迭代后真损失为281.05073285795436，假损失为193.00213398769276
# 第14次迭代后真损失为279.53934637952426，假损失为192.14803837560513
# 第15次迭代后真损失为278.08227498698244，假损失为191.30091054579015
# 第16次迭代后真损失为276.6770086240344，假损失为190.46396454538197
# 第17次迭代后真损失为275.3223112939713，假损失为189.63949754051677
# 第18次迭代后真损失为274.0178172250351，假损失为188.8291770097102
# 第19次迭代后真损失为272.76373713363125，假损失为188.03423860481848
# 第20次迭代后真损失为271.56063205911266，假损失为187.25561953036103
# 第21次迭代后真损失为270.4092313665115，假损失为186.49404606980826
# 第22次迭代后真损失为269.31028291893375，假损失为185.7500892278468
# 第23次迭代后真损失为268.2644300061192，假损失为185.02419894256695
# 第24次迭代后真损失为267.27211312247897，假损失为184.31672461951456
# 第25次迭代后真损失为266.3334961971332，假损失为183.627927609088
# 第26次迭代后真损失为265.44841709962，假损失为182.9579895311004
# 第27次迭代后真损失为264.6163616846824，假损失为182.30701895608456
# 第28次迭代后真损失为263.83645968947906，假损失为181.67505784312806
# 第29次迭代后真损失为263.1074997692704，假损失为181.06208829756523
# 第30次迭代后真损失为262.4279600920641，假损失为180.46803964290393
# 第31次迭代后真损失为261.79605036743703，假损失为179.8927954822236
# 第32次迭代后真损失为261.20976103233176，假损失为179.33620031721495
# 第33次迭代后真损失为260.6669155484883，假损失为178.79806534228564
# 第34次迭代后真损失为260.16522230954513，假损失为178.2781731724217
# 第35次迭代后真损失为259.70232339982937，假损失为177.77628143598736
# 第36次迭代后真损失为259.27583827056725，假损失为177.29212532024854
# 第37次迭代后真损失为258.8834011957723，假损失为176.82541926963407
# 第38次迭代后真损失为258.5226920613605，假损失为176.37585809452435
# 第39次迭代后真损失为258.1914605833103，假损失为175.9431177557779
# 第40次迭代后真损失为257.8875444315113，假损失为175.5268560596668
# 第41次迭代后真损失为257.6088819664607，假损失为175.1267134447049
# 第42次迭代后真损失为257.3535204017657，假损失为174.74231398014717
# 第43次迭代后真损失为257.1196202177537，假损失为174.37326663655315
# 第44次迭代后真损失为256.9054566012406，假损失为174.01916683861376
# 第45次迭代后真损失为256.7094186000702，假损失为173.6795982726627
# 第46次迭代后真损失为256.5300065788511，假损失为173.35413489645254
# 第47次迭代后真损失为256.36582845855384，假损失为173.0423430855538
# 第48次迭代后真损失为256.21559512616807，假损失为172.74378384695848
# 第49次迭代后真损失为256.07811531604034，假损失为172.4580150335706
# 第50次迭代后真损失为255.95229019351095，假损失为172.18459350094736
# 第51次迭代后真损失为255.83710781376587，假损失为171.92307715782158
# 第52次迭代后真损失为255.73163758313342，假损失为171.6730268730838
# 第53次迭代后真损失为255.63502481459255，假损失为171.4340082128411
# 第54次迭代后真损失为255.54648544216474，假损失为171.20559299121282
# 第55次迭代后真损失为255.46530093839866，假损失为170.9873606272143
# 第56次迭代后真损失为255.39081346383983，假损失为170.77889930725243
# 第57次迭代后真损失为255.32242126596773，假损失为170.57980695839362
# 第58次迭代后真损失为255.25957433663376，假损失为170.38969204178227
# 第59次迭代后真损失为255.2017703307735，假损失为170.20817417851055
# 第60次迭代后真损失为255.1485507445768，假损失为170.03488462209975
# 第61次迭代后真损失为255.0994973479205，假损失为169.8694665927155
# 第62次迭代后真损失为255.0542288634321，假损失为169.71157548852267
# 第63次迭代后真损失为255.0123978828247，假损失为169.5608789893097
# 第64次迭代后真损失为254.97368800994153，假损失为169.4170570668941
# 第65次迭代后真损失为254.93781121919207，假损失为169.27980191590007
# 第66次迭代后真损失为254.90450541760538，假损失为169.14881781745706
# 第67次迭代后真损失为254.87353219855095，假损失为169.02382094720372
# 第68次迭代后真损失为254.84467477519246，假损失为168.9045391378253
# 第69次迭代后真损失为254.81773608190827，假损失为168.7907116051882
# 第70次迭代后真损失为254.79253703221545，假损失为168.68208864603244
# 第71次迭代后真损失为254.7689149221177，假损失为168.5784313141571
# 第72次迭代后真损失为254.74672196824685，假损失为168.47951108105184
# 第73次迭代后真损失为254.7258239706814，假损失为168.38510948609263
# 第74次迭代后真损失为254.70609909084226，假损失为168.29501778061046
# 第75次迭代后真损失为254.6874367354175，假损失为168.209036569454
# 第76次迭代后真损失为254.66973653783322，假损失为168.12697545307174
# 第77次迭代后真损失为254.6529074293133，假损失为168.048652672575
# 第78次迭代后真损失为254.6368667921341，假损失为167.97389475979915
# 第79次迭代后真损失为254.62153968818086，假损失为167.9025361939749
# 第80次迭代后真损失为254.60685815643654，假损失为167.83441906627027
# 第81次迭代后真损失为254.59276057349547，假损失为167.76939275318125
# 第82次迭代后真损失为254.57919107166174，假损失为167.70731359949585
# 第83次迭代后真损失为254.56609900961735，假损失为167.64804461134773
# 第84次迭代后真损失为254.55343849104878，假损失为167.59145515970468
# 第85次迭代后真损失为254.5411679270019，假损失为167.53742069449586
# 第86次迭代后真损失为254.52924963808132，假损失为167.48582246944846
# 第87次迭代后真损失为254.5176494929399，假损失为167.43654727762677
# 第88次迭代后真损失为254.50633657981376，假损失为167.389487197576
# 第89次迭代后真损失为254.49528290811986，假损失为167.3445393499086
# 第90次迭代后真损失为254.4844631374141，假损失为167.30160566413295
# 第91次迭代后真损失为254.4738543312283，假损失为167.26059265547434
# 第92次迭代后真损失为254.46343573352664，假损失为167.2214112114142
# 第93次迭代后真损失为254.45318856573152，假损失为167.18397638765336
# 第94次迭代后真损失为254.44309584243652，假损失为167.1482072131889
# 第95次迭代后真损失为254.43314220410326，假损失为167.11402650418324
# 第96次迭代后真损失为254.4233137651928，假损失为167.0813606863011
# 第97次迭代后真损失为254.41359797631233，假损失为167.05013962519118
# 第98次迭代后真损失为254.4039834990982，假损失为167.02029646478408
# 第99次迭代后真损失为254.39446009266177，假损失为166.99176747308886
# 第100次迭代后真损失为254.38501851053917，假损失为166.9644918951681
# 第101次迭代后真损失为254.37565040718215，假损失为166.93841181299004
# 第102次迭代后真损失为254.36634825310438，假损失为166.91347201185044
# 第103次迭代后真损失为254.35710525789628，假损失为166.88961985307844
# 第104次迭代后真损失为254.34791530037842，假损失为166.8668051527367
# 第105次迭代后真损失为254.33877286523688，假损失为166.84498006605543
# 第106次迭代后真损失为254.32967298554348，假损失为166.82409897732356
# 第107次迭代后真损失为254.32061119062044，假损失为166.8041183949951
# 第108次迭代后真损失为254.3115834587537，假损失为166.78499685176388
# 第109次迭代后真损失为254.30258617430874，假损失为166.76669480937525
# 第110次迭代后真损失为254.29361608884352，假损失为166.74917456795237
# 第111次迭代后真损失为254.28467028585055，假损失为166.73240017962297
# 第112次迭代后真损失为254.27574614878628，假损失为166.7163373662441
# 第113次迭代后真损失为254.26684133209775，假损失为166.70095344103132
# 第114次迭代后真损失为254.25795373495217，假损失为166.6862172339017
# 第115次迭代后真损失为254.24908147743565，假损失为166.67209902036316
# 第116次迭代后真损失为254.24022287898285，假损失为166.658570453768
# 第117次迭代后真损失为254.23137643883305，假损失为166.64560450078292
# 第118次迭代后真损失为254.2225408183293，假损失为166.6331753799121
# 第119次迭代后真损失为254.21371482488357，假损失为166.6212585029323
# 第120次迭代后真损失为254.2048973974601，假损失为166.60983041909904
# 第121次迭代后真损失为254.19608759342887，假损失为166.59886876199056
# 第122次迭代后真损失为254.18728457667132，假损失为166.58835219886538
# 第123次迭代后真损失为254.17848760681056，假损失为166.5782603824115
# 第124次迭代后真损失为254.16969602947393，假损失为166.56857390477296
# 第125次迭代后真损失为254.1609092674822，假损失为166.55927425374514
# 第126次迭代后真损失为254.15212681288304，假损失为166.55034377103578
# 第127次迭代后真损失为254.14334821975285，假损失为166.54176561249255
# 第128次迭代后真损失为254.13457309768708，假损失为166.53352371020128
# 第129次迭代后真损失为254.12580110592558，假损失为166.52560273637084
# 第130次迭代后真损失为254.1170319480431，假损失为166.51798806891313
# 第131次迭代后真损失为254.10826536716078，假损失为166.51066575864226
# 第132次迭代后真损失为254.09950114162368，假损失为166.50362249801245
# 第133次迭代后真损失为254.0907390811028，假损失为166.49684559132507
# 第134次迭代后真损失为254.0819790230825，假损失为166.49032292633174
# 第135次迭代后真损失为254.07322082969506，假损失为166.48404294716815
# 第136次迭代后真损失为254.06446438487282，假损失为166.47799462855642
# 第137次迭代后真损失为254.05570959178272，假损失为166.4721674512155
# 第138次迭代后真损失为254.0469563705203，假损失为166.46655137842026
# 第139次迭代后真损失为254.03820465604025，假损失为166.46113683365948
# 第140次迭代后真损失为254.02945439629454，假损失为166.45591467933565
# 第141次迭代后真损失为254.0207055505634，假损失为166.4508761964596
# 第142次迭代后真损失为254.0119580879614，假损失为166.44601306529512
# 第143次迭代后真损失为254.00321198609612，假损失为166.44131734690544
# 第144次迭代后真损失为253.99446722987142，假损失为166.43678146555808
# 第145次迭代后真损失为253.98572381041555，假损失为166.43239819195577
# 第146次迭代后真损失为253.97698172412748，假损失为166.42816062724006
# 第147次迭代后真损失为253.96824097182306，假损失为166.42406218774778
# 第148次迭代后真损失为253.95950155798158，假损失为166.42009659047216
# 第149次迭代后真损失为253.95076349006882，假损失为166.41625783920264
# 第150次迭代后真损失为253.94202677794172，假损失为166.41254021130663
# 第151次迭代后真损失为253.93329143331988，假损失为166.408938245128
# 第152次迭代后真损失为253.92455746932117，假损失为166.40544672796992
# 第153次迭代后真损失为253.9158249000478，假损失为166.40206068463615
# 第154次迭代后真损失为253.90709374022651，假损失为166.39877536650312
# 第155次迭代后真损失为253.89836400489474，假损失为166.3955862411004
# 第156次迭代后真损失为253.88963570912043，假损失为166.39248898217295
# 第157次迭代后真损失为253.8809088677663，假损失为166.38947946020616
# 第158次迭代后真损失为253.87218349528，假损失为166.38655373338602
# 第159次迭代后真损失为253.86345960551702，假损失为166.38370803898283
# 第160次迭代后真损失为253.8547372115869，假损失为166.3809387851314
# 第161次迭代后真损失为253.84601632572395，假损失为166.37824254298988
# 第162次迭代后真损失为253.83729695917899，假损失为166.37561603926443
# 第163次迭代后真损失为253.82857912212856，假损失为166.37305614907885
# 第164次迭代后真损失为253.81986282359853，假损失为166.37055988917183
# 第165次迭代后真损失为253.8111480714068，假损失为166.36812441141242
# 第166次迭代后真损失为253.80243487211476，假损失为166.36574699661008
# 第167次迭代后真损失为253.79372323099048，假损失为166.36342504861463
# 第168次迭代后真损失为253.78501315198568，假损失为166.36115608868687
# 第169次迭代后真损失为253.7763046377153，假损失为166.35893775012886
# 第170次迭代后真损失为253.7675976894487，假损失为166.3567677731624
# 第171次迭代后真损失为253.75889230710928，假损失为166.35464400004338
# 第172次迭代后真损失为253.75018848927374，假损失为166.3525643704017
# 第173次迭代后真损失为253.7414862331827，假损失为166.3505269167937
# 第174次迭代后真损失为253.7327855347521，假损失为166.34852976046423
# 第175次迭代后真损失为253.7240863885897，假损失为166.3465711072985
# 第176次迭代后真损失为253.7153887880125，假损失为166.3446492439639
# 第177次迭代后真损失为253.70669272507192，假损失为166.34276253422775
# 第178次迭代后真损失为253.6979981905748，假损失为166.34090941544375
# 第179次迭代后真损失为253.68930517411002，假损失为166.33908839520345
# 第180次迭代后真损失为253.6806136640777，假损失为166.33729804813615
# 第181次迭代后真损失为253.6719236477147，假损失为166.3355370128609
# 第182次迭代后真损失为253.66323511112682，假损失为166.3338039890753
# 第183次迭代后真损失为253.65454803931672，假损失为166.3320977347799
# 第184次迭代后真损失为253.64586241621555，假损失为166.33041706362846
# 第185次迭代后真损失为253.63717822471355，假损失为166.32876084240087
# 第186次迭代后真损失为253.62849544668953，假损失为166.32712798859083
# 第187次迭代后真损失为253.6198140630439，假损失为166.32551746810606
# 第188次迭代后真损失为253.61113405372697，假损失为166.32392829307113
# 第189次迭代后真损失为253.6024553977703，假损失为166.32235951973522
# 第190次迭代后真损失为253.59377807331597，假损失为166.32081024646902
# 第191次迭代后真损失为253.58510205764642，假损失为166.31927961186153
# 第192次迭代后真损失为253.57642732721385，假损失为166.31776679289575
# 第193次迭代后真损失为253.56775385766537，假损失为166.31627100321612
# 第194次迭代后真损失为253.55908162387541，假损失为166.3147914914669
# 第195次迭代后真损失为253.55041059996861，假损失为166.3133275397126
# 第196次迭代后真损失为253.5417407593475，假损失为166.31187846192867
# 第197次迭代后真损失为253.53307207471926，假损失为166.3104436025599
# 第198次迭代后真损失为253.5244045181175，假损失为166.3090223351463
# 第199次迭代后真损失为253.51573806092918，假损失为166.30761406101155
# fm 训练集acc：0.754000
# fm 测试集acc：0.809701
