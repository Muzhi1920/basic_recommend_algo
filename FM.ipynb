# %%
from __future__ import division
from math import exp
from numpy import *
import numpy as np
from random import normalvariate
import pandas as pd
# reference
# https://segmentfault.com/a/1190000020254554
# https://blog.csdn.net/john_xyz/article/details/78933253

# %%
train_data = 'fm_data/train.txt'
test_data = 'fm_data/test.txt'

def preprocess(data):
    feature=np.array(data.iloc[:,:-1])
    label=data.iloc[:,-1].map(lambda x: 1 if x==1 else -1)
    zmax, zmin = feature.max(axis=0), feature.min(axis=0)
    feature = (feature - zmin) / (zmax - zmin)
    label=np.array(label)
    return feature,label

def sigmoid(x):
    return 1.0 / (1 + exp(-x))

# %%
def SGD_FM(data, label, k, iter):
    m, num_feature = shape(data)
    alpha = 0.01
    w = zeros((num_feature, 1))      #一阶特征的系数
    w_0 = 0.0
    v = normalvariate(0, 0.2) * ones((num_feature, k))   #即生成辅助向量，用来训练二阶交叉特征的系数

    for it in range(iter):
        true_loss = 0.0
        false_loss = 0.0
        for x in range(m):
            fm_1 = data[x] * v
            fm_2 = multiply(data[x], data[x]) * multiply(v, v)
            fm = sum(multiply(fm_1, fm_1) - fm_2) / 2.
            y = w_0 + data[x] * w + fm  # FM预测输出
            loss = sigmoid(label[x] * y[0, 0])-1    #真实损失过大，与真实损失相像。loss针对当前样本，不做为最后loss衡量
            true_loss += -np.log(sigmoid(label[x] * y[0, 0]))
            false_loss += -loss
            w_0 -= alpha * loss * label[x]
            for i in range(num_feature):
                if data[x, i] != 0:
                    w[i, 0] -= alpha * loss * label[x] * data[x, i]
                    for j in range(k):
                        v[i, j] -= alpha * loss * label[x] * (data[x, i] * fm_1[0, j] - v[i, j] * data[x, i] * data[x, i])
        print("第{}次迭代后真损失为{}，假损失为{}".format(it, true_loss, false_loss))
    return w_0, w, v
def predict(data, label, w_0, w, v):
    m, _ = shape(data)
    err = 0
    num = 0
    result = []
    for x in range(m):   #计算每一个样本的误差
        num += 1
        fm_1 = data[x] * v
        fm_2 = multiply(data[x], data[x]) * multiply(v, v)
        fm = sum(multiply(fm_1, fm_1) - fm_2) / 2.
        y = w_0 + data[x] * w + fm  # 计算预测的输出
        prop = sigmoid(y[0, 0])
        result.append(prop)
        if prop < 0.5 and label[x] == 1.0:
            err += 1
        elif prop >= 0.5 and label[x] == -1.0:
            err += 1
        else:
            continue
    return float(err) / num

# %%
if __name__ == '__main__':
    train = pd.read_csv(train_data)
    test = pd.read_csv(test_data)
    x_train, y_train = preprocess(train)
    x_test, y_test = preprocess(test)
    w_0, w, v = SGD_FM(mat(x_train), y_train, 20, 200)
    print("训练集acc：%f" % (1 - predict(mat(x_train), y_train, w_0, w, v)))
    print("测试集acc：%f" % (1 - predict(mat(x_test), y_test, w_0, w, v)))
# Out:
# 第0次迭代后真损失为325.60958676580316，假损失为235.39282063835878
# 第1次迭代后真损失为312.24573059175793，假损失为225.91126284552325
# 第2次迭代后真损失为305.8286962362917，假损失为221.3054328766722
# 第3次迭代后真损失为300.2687244069961，假损失为217.03457981261448
# 第4次迭代后真损失为295.6065733168583，假损失为213.1427460113754
# 第5次迭代后真损失为291.68603503196925，假损失为209.66831296788033
# 第6次迭代后真损失为288.34354670622275，假损失为206.59114848114154
# 第7次迭代后真损失为285.4422830289174，假损失为203.86579034598196
# 第8次迭代后真损失为282.8784042473046，假损失为201.44107199745096
# 第9次迭代后真损失为280.5770146652994，假损失为199.2691324293176
# 第10次迭代后真损失为278.48552313384084，假损失为197.30864744247316
# 第11次迭代后真损失为276.56742407644674，假损失为195.52534374377063
# 第12次迭代后真损失为274.79736000468006，假损失为193.8913979996819
# 第13次迭代后真损失为273.1574914246541，假损失为192.38447757386643
# 第14次迭代后真损失为271.63494268460937，假损失为190.98675149058158
# 第15次迭代后真损失为270.2200566757756，假损失为189.683998827541
# 第16次迭代后真损失为268.90522850814216，假损失为188.46485227551548
# 第17次迭代后真损失为267.68414112646377，假损失为187.3201772756066
# 第18次迭代后真损失为266.5512742725923，假损失为186.24257310372096
# 第19次迭代后真损失为265.501596661832，假损失为185.22597820015213
# 第20次迭代后真损失为264.5303795882942，假损失为184.2653620271891
# 第21次迭代后真损失为263.6330901196784，假损失为183.35648725706645
# 第22次迭代后真损失为262.80533567121347，假损失为182.49572811627388
# 第23次迭代后真损失为262.0428409256002，假损失为181.67993283182983
# 第24次迭代后真损失为261.3414442379203，假损失为180.90632017201781
# 第25次迭代后真损失为260.69710485803336，假损失为180.17240196494868
# 第26次迭代后真损失为260.1059151996677，假损失为179.47592516235477
# 第27次迭代后真损失为259.56411441804596，假损失为178.81482846268528
# 第28次迭代后真损失为259.0681009956539，假损失为178.18720970604107
# 第29次迭代后真损失为258.61444304800824，假损失为177.5913012119928
# 第30次迭代后真损失为258.19988575957126，假损失为177.0254509734316
# 第31次迭代后真损失为257.8213558234215，假损失为176.48810817825856
# 第32次迭代后真损失为257.4759630469523，假损失为175.97781194201482
# 第33次迭代后真损失为257.16099944745713，假损失为175.49318243284986
# 第34次迭代后真损失为256.873936234131，假损失为175.03291378513637
# 第35次迭代后真损失为256.61241908688424，假损失为174.59576835307917
# 第36次迭代后真损失为256.37426212034785，假损失为174.1805719685603
# 第37次迭代后真损失为256.1574408801551，假损失为173.78620995078774
# 第38次迭代后真损失为255.96008466938954，假损失为173.41162367779629
# 第39次迭代后真损失为255.78046845327853，假损失为173.05580757730502
# 第40次迭代后真损失为255.61700454384237，假损失为172.7178064308306
# 第41次迭代后真损失为255.46823422540575，假损失为172.39671291295315
# 第42次迭代后真损失为255.33281944708895，假损失为172.09166530909204
# 第43次迭代后真损失为255.20953467955448，假损失为171.801845371501
# 第44次迭代后真损失为255.09725900963113，假损失为171.5264762854726
# 第45次迭代后真损失为254.9949685272753，假损失为171.26482072681014
# 第46次迭代后真损失为254.90172904382325，假损失为171.01617899818967
# 第47次迭代后真损失为254.81668916799043，假损失为170.77988723664743
# 第48次迭代后真损失为254.7390737559557，假损失为170.5553156875698
# 第49次迭代后真损失为254.66817774372393，假损失为170.34186704260688
# 第50次迭代后真损失为254.60336036335522，假损失为170.13897484016036
# 第51次迭代后真损失为254.54403973940066，假损失为169.94610192778507
# 第52次迭代后真损失为254.4896878576562，假损失为169.76273898610933
# 第53次迭代后真损失为254.43982589509304，假损失为169.58840311394195
# 第54次迭代后真损失为254.39401989730382，假损失为169.42263647408225
# 第55次迭代后真损失为254.35187678796657，假损失为169.26500499917609
# 第56次迭代后真损失为254.31304069354576，假损失为169.11509715670496
# 第57次迭代后真损失为254.2771895656541，假损失为168.97252277195585
# 第58次迭代后真损失为254.24403208308922，假损失为168.83691190760936
# 第59次迭代后真损失为254.21330481548762，假损失为168.70791379836658
# 第60次迭代后真损失为254.1847696307339，假损失为168.58519583889645
# 第61次迭代后真损失为254.15821132868058，假损失为168.46844262324066
# 第62次迭代后真损失为254.1334354842987，假损失为168.357355033736
# 第63次迭代后真损失为254.11026648407955，假损失为168.25164937744447
# 第64次迭代后真损失为254.08854574030974，假损失为168.15105656805446
# 第65次迭代后真损失为254.06813006866597，假损失为168.05532135120802
# 第66次迭代后真损失为254.04889021546202，假损失为167.96420157122347
# 第67次迭代后真损失为254.03070952177194，假损失为167.8774674772077
# 第68次迭代后真损失为254.01348271252556，假损失为167.79490106660185
# 第69次迭代后真损失为253.99711479954286，假损失为167.71629546425342
# 第70次迭代后真损失为253.98152008831525，假损失为167.64145433517126
# 第71次迭代后真损失为253.96662127912523，假损失为167.57019132918504
# 第72次迭代后真损失为253.95234865388394，假损失为167.50232955580665
# 第73次迭代后真损失为253.93863934076154，假损失为167.43770108765463
# 第74次迭代后真损失为253.9254366493657，假损失为167.37614649089159
# 第75次迭代后真损失为253.91268946986645，假损失为167.31751438118272
# 第76次迭代后真损失为253.90035173002858，假损失为167.2616610037668
# 第77次迭代后真损失为253.88838190466348，假损失为167.2084498363061
# 第78次迭代后真损失为253.8767425725133，假损失为167.15775121323432
# 第79次迭代后真损失为253.86540001603072，假损失为167.10944197041715
# 第80次迭代后真损失为253.85432385994713，假损失为167.0634051089742
# 第81次迭代后真损失为253.84348674489078，假损失为167.01952947720105
# 第82次迭代后真损失为253.83286403268917，假损失为166.9777094695725
# 第83次迭代后真损失为253.8224335402835，假损失为166.93784474186927
# 第84次迭代后真损失为253.8121752995009，假损失为166.8998399415321
# 第85次迭代后真损失为253.8020713401746，假损失为166.86360445238668
# 第86次迭代后真损失为253.79210549434413，假损失为166.82905215294196
# 第87次迭代后真损失为253.78226321950766，假损失为166.79610118750315
# 第88次迭代后真损失为253.7725314390535，假损失为166.7646737493887
# 第89次迭代后真损失为253.76289839822726，假损失为166.73469587558125
# 第90次迭代后真损失为253.75335353410475，假损失为166.70609725217872
# 第91次迭代后真损失为253.74388735822745，假损失为166.6788110300497
# 第92次迭代后真损失为253.73449135065715，假损失为166.65277365013472
# 第93次迭代后真损失为253.7251578643486，假损失为166.62792467786082
# 第94次迭代后真损失为253.71588003883414，假损失为166.60420664617442
# 第95次迭代后真损失为253.70665172231708，假损失为166.58156490672053
# 第96次迭代后真损失为253.69746740135903，假损失为166.5599474887259
# 第97次迭代后真损失为253.6883221374182，假损失为166.53930496517168
# 第98次迭代后真损失为253.67921150958054，假损失为166.51959032585822
# 第99次迭代后真损失为253.67013156287894，假损失为166.50075885699204
# 第100次迭代后真损失为253.66107876165748，假损失为166.4827680269477
# 第101次迭代后真损失为253.65204994749402，假损失为166.4655773778723
# 第102次迭代后真损失为253.6430423012362，假损失为166.44914842281918
# 第103次迭代后真损失为253.63405330875463，假损失为166.43344454812078
# 第104次迭代后真损失为253.62508073004923，假损失为166.4184309207233
# 第105次迭代后真损失为253.61612257138745，假损失为166.4040744002152
# 第106次迭代后真损失为253.60717706017587，假损失为166.3903434553107
# 第107次迭代后真损失为253.5982426223053，假损失为166.3772080845475
# 第108次迭代后真损失为253.58931786172386，假损失为166.36463974098427
# 第109次迭代后真损失为253.5804015420269，假损失为166.35261126068067
# 第110次迭代后真损失为253.57149256986375，假损失为166.34109679477564
# 第111次迭代后真损失为253.56258997998617，假损失为166.33007174496333
# 第112次迭代后真损失为253.55369292178406，假损失为166.3195127022028
# 第113次迭代后真损失为253.5448006471534，假损失为166.30939738848517
# 第114次迭代后真损失为253.53591249957748，假损失为166.29970460150759
# 第115次迭代后真损失为253.52702790429666，假损失为166.29041416210336
# 第116次迭代后真损失为253.51814635946158，假损失为166.28150686428154
# 第117次迭代后真损失为253.50926742818095，假损失为166.27296442775184
# 第118次迭代后真损失为253.50039073136222，假损失为166.26476945280174
# 第119次迭代后真损失为253.49151594128418，假损失为166.25690537740562
# 第120次迭代后真损失为253.48264277581654，假损失为166.2493564364591
# 第121次迭代后真损失为253.47377099323333，假损失为166.24210762302357
# 第122次迭代后真损失为253.46490038755132，假损失为166.23514465148347
# 第123次迭代后真损失为253.4560307843546，假损失为166.22845392251966
# 第124次迭代后真损失为253.4471620370459，假损失为166.22202248980486
# 第125次迭代后真损失为253.4382940234886，假损失为166.21583802833865
# 第126次迭代后真损失为253.42942664299997，假损失为166.2098888043363
# 第127次迭代后真损失为253.42055981366053，假损失为166.20416364659533
# 第128次迭代后真损失为253.41169346990893，假损失为166.19865191926502
# 第129次迭代后真损失为253.40282756039034，假损失为166.1933434959515
# 第130次迭代后真损失为253.39396204603952，假损失为166.18822873508552
# 第131次迭代后真损失为253.38509689836903，假损失为166.1832984564994
# 第132次迭代后真损失为253.37623209794575，假损失为166.1785439191451
# 第133次迭代后真损失为253.3673676330334，假损失为166.17395679989923
# 第134次迭代后真损失为253.3585034983906，假损失为166.16952917340436
# 第135次迭代后真损失为253.3496396941991，假损失为166.1652534928896
# 第136次迭代后真损失为253.34077622511745，假损失为166.1611225719267
# 第137次迭代后真损失为253.33191309944527，假损失为166.15712956707517
# 第138次迭代后真损失为253.32305032838056，假损失为166.15326796136682
# 第139次迭代后真损失为253.31418792537082，假损失为166.1495315485992
# 第140次迭代后真损失为253.30532590554012，假损失为166.14591441838604
# 第141次迭代后真损失为253.29646428518691，假损失为166.14241094193648
# 第142次迭代后真损失为253.28760308134557，假损失为166.1390157585227
# 第143次迭代后真损失为253.27874231140444，假损失为166.13572376260527
# 第144次迭代后真损失为253.26988199277534，假损失为166.13253009157995
# 第145次迭代后真损失为253.26102214260482，假损失为166.1294301141191
# 第146次迭代后真损失为253.25216277753066，假损失为166.12641941907728
# 第147次迭代后真损失为253.24330391346948，假损失为166.12349380493308
# 第148次迭代后真损失为253.23444556543856，假损失为166.12064926974196
# 第149次迭代后真损失为253.22558774740554，假损失为166.11788200157486
# 第150次迭代后真损失为253.21673047216237，假损失为166.1151883694163
# 第151次迭代后真损失为253.20787375122418，假损失为166.11256491450587
# 第152次迭代后真损失为253.1990175947438，假损失为166.11000834209378
# 第153次迭代后真损失为253.1901620114461，假损失为166.1075155135956
# 第154次迭代后真损失为253.18130700857765，假损失为166.10508343912718
# 第155次迭代后真损失为253.1724525918668，假损失为166.1027092703949
# 第156次迭代后真损失为253.16359876550206，假损失为166.10039029393172
# 第157次迭代后真损失为253.15474553211178，假损失为166.09812392465935
# 第158次迭代后真损失为253.14589289276134，假损失为166.0959076997574
# 第159次迭代后真损失为253.13704084695053，假损失为166.09373927283013
# 第160次迭代后真损失为253.12818939262388，假损失为166.09161640835245
# 第161次迭代后真损失为253.1193385261822，假损失为166.08953697638267
# 第162次迭代后真损失为253.11048824250295，假损失为166.0874989475308
# 第163次迭代后真损失为253.10163853495885，假损失为166.08550038816742
# 第164次迭代后真损失为253.09278939544734，假损失为166.08353945586242
# 第165次迭代后真损失为253.08394081441608，假损失为166.08161439504278
# 第166次迭代后真损失为253.07509278089623，假损失为166.0797235328611
# 第167次迭代后真损失为253.06624528253369，假损失为166.07786527525744
# 第168次迭代后真损失为253.05739830562362，假损失为166.07603810321456
# 第169次迭代后真损失为253.0485518351467，假损失为166.07424056919032
# 第170次迭代后真损失为253.03970585480315，假损失为166.07247129372277
# 第171次迭代后真损失为253.03086034705186，假损失为166.07072896219398
# 第172次迭代后真损失为253.022015293145，假损失为166.06901232175463
# 第173次迭代后真损失为253.01317067316748，假损失为166.06732017839045
# 第174次迭代后真损失为253.0043264660709，假损失为166.06565139413257
# 第175次迭代后真损失为252.9954826497128，假损失为166.06400488439888
# 第176次迭代后真损失为252.9866392008916，假损失为166.06237961546557
# 第177次迭代后真损失为252.97779609538205，假损失为166.0607746020552
# 第178次迭代后真损失为252.96895330797113，假损失为166.059188905044
# 第179次迭代后真损失为252.96011081249225，假损失为166.057621629277
# 第180次迭代后真损失为252.951268581859，假损失为166.05607192148682
# 第181次迭代后真损失为252.9424265880972，假损失为166.054538968313
# 第182次迭代后真损失为252.93358480237757，假损失为166.0530219944159
# 第183次迭代后真损失为252.92474319504768，假损失为166.05152026067958
# 第184次迭代后真损失为252.91590173566064，假损失为166.05003306250063
# 第185次迭代后真损失为252.90706039300483，假损失为166.04855972815966
# 第186次迭代后真损失为252.89821913513302，假损失为166.04709961726843
# 第187次迭代后真损失为252.88937792938952，假损失为166.04565211929372
# 第188次迭代后真损失为252.88053674243665，假损失为166.04421665214753
# 第189次迭代后真损失为252.87169554027966，假损失为166.04279266084973
# 第190次迭代后真损失为252.86285428829189，假损失为166.0413796162482
# 第191次迭代后真损失为252.85401295123813，假损失为166.039977013805
# 第192次迭代后真损失为252.84517149329955，假损失为166.03858437243767
# 第193次迭代后真损失为252.83632987809168，假损失为166.0372012334164
# 第194次迭代后真损失为252.8274880686888，假损失为166.03582715931324
# 第195次迭代后真损失为252.81864602764247，假损失为166.0344617330012
# 第196次迭代后真损失为252.8098037170012，假损失为166.03310455670064
# 第197次迭代后真损失为252.8009610983301，假损失为166.03175525107432
# 第198次迭代后真损失为252.79211813272704，假损失为166.03041345435645
# 第199次迭代后真损失为252.7832747808394，假损失为166.02907882153585
# 训练集acc：0.751503
# 测试集acc：0.812734
